# %% [markdown]
# <h1>Weather Forecasting using Deep Neural Network</h1>

# %% [markdown]
# <h2>Importing PANDAS</h2>
# <h3>Importing Weather Data provided by <a href="https://www.ncei.noaa.gov/cdo-web/search "> NOAA</a></h3>

# %%
import pandas as pd

weather= pd.read_csv("C:\\Users\\Deepak\\Documents\\deepak_docs\\weather.csv", index_col="DATE")

# %% [markdown]
# <h3>This Weather Data has following major columns:</h3>
# <ol>
#     <li>'STATION'</li>
#     <li>'NAME'</li>
#     <li>'ACMH'</li>
#     <li>'ACSH'</li>
#     <li>'AWND'</li>
#     <li>'FMTM'</li>
#     <li>'PGTM'</li>
#     <li>'PRCP'</li>
#     <li>'SNOW'</li>
#     <li>'SNWD'</li>
#     <li>'TAVG'</li>
#     <li>'TMAX'</li>
#     <li>'TMIN'</li>
# </ol>N

# %%
weather.columns
# Out:
# Index(['STATION', 'NAME', 'ACMH', 'ACSH', 'AWND', 'FMTM', 'PGTM', 'PRCP',
#        'SNOW', 'SNWD', 'TAVG', 'TMAX', 'TMIN', 'TSUN', 'WDF1', 'WDF2', 'WDF5',
#        'WDFG', 'WDFM', 'WESD', 'WSF1', 'WSF2', 'WSF5', 'WSFG', 'WSFM', 'WT01',
#        'WT02', 'WT03', 'WT04', 'WT05', 'WT06', 'WT07', 'WT08', 'WT09', 'WT11',
#        'WT13', 'WT14', 'WT15', 'WT16', 'WT17', 'WT18', 'WT19', 'WT21', 'WT22',
#        'WV01'],
#       dtype='object')

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 01-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 02-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 03-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 04-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 05-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 06-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   5.82
# 07-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   8.72
# 08-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  11.18
# 09-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  10.51
# 10-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
# ...

# %%
null_pct=weather.apply(pd.isnull).sum()/weather.shape[0]

# %%
weather.apply(pd.isnull).sum()
# Out:
# STATION        0
# NAME           0
# ACMH       10239
# ACSH       10238
# AWND        5116
# FMTM        9730
# PGTM        7585
# PRCP           1
# SNOW           2
# SNWD           4
# TAVG       13123
# TMAX           1
# TMIN           1
# TSUN       19823
# WDF1       10243
# WDF2        9618
# WDF5        9701
# WDFG       14733
# WDFM       19853
# WESD       13783
# WSF1       10240
# WSF2        9618
# WSF5        9702
# WSFG       12391
# WSFM       19853
# WT01       12503
# WT02       18558
# WT03       18530
# WT04       19508
# WT05       19490
# WT06       19672
# WT07       19746
# WT08       15905
# WT09       19714
# WT11       19840
# WT13       17669
# WT14       18967
# WT15       19812
# WT16       13277
# WT17       19794
# WT18       18687
# WT19       19853
# WT21       19849
# WT22       19805
# WV01       19853
# dtype: int64

# %%
null_pct
# Out:
# STATION    0.000000
# NAME       0.000000
# ACMH       0.515715
# ACSH       0.515664
# AWND       0.257681
# FMTM       0.490078
# PGTM       0.382039
# PRCP       0.000050
# SNOW       0.000101
# SNWD       0.000201
# TAVG       0.660975
# TMAX       0.000050
# TMIN       0.000050
# TSUN       0.998439
# WDF1       0.515916
# WDF2       0.484436
# WDF5       0.488617
# WDFG       0.742067
# WDFM       0.999950
# WESD       0.694218
# WSF1       0.515765
# WSF2       0.484436
# WSF5       0.488667
# WSFG       0.624106
# WSFM       0.999950
# WT01       0.629747
# WT02       0.934723
# WT03       0.933313
# WT04       0.982573
# WT05       0.981666
# WT06       0.990833
# WT07       0.994560
# WT08       0.801098
# WT09       0.992949
# WT11       0.999295
# WT13       0.889947
# WT14       0.955324
# WT15       0.997885
# WT16       0.668732
# WT17       0.996978
# WT18       0.941221
# WT19       0.999950
# WT21       0.999748
# WT22       0.997532
# WV01       0.999950
# ...

# %%
valid_columns=weather.columns[null_pct<.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather = weather[valid_columns].copy()

# %%
weather.columns =weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 01-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 02-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 03-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 04-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 05-01-1970  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 06-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 07-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 08-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 09-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 10-05-2024  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN   NaN   NaN
#
#             tmax  tmin
# DATE
# ...

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       1
# snow       2
# snwd       4
# tmax       1
# tmin       1
# dtype: int64

# %%
weather =weather.ffill()

# %%
weather.apply(pd.isnull).sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax       float64
# tmin       float64
# dtype: object

# %%
weather.index
# Out:
# Index(['01-01-1970', '02-01-1970', '03-01-1970', '04-01-1970', '05-01-1970',
#        '06-01-1970', '07-01-1970', '08-01-1970', '09-01-1970', '10-01-1970',
#        ...
#        '01-05-2024', '02-05-2024', '03-05-2024', '04-05-2024', '05-05-2024',
#        '06-05-2024', '07-05-2024', '08-05-2024', '09-05-2024', '10-05-2024'],
#       dtype='object', name='DATE', length=19854)

# %%
weather.index = pd.to_datetime(weather.index, format='%d-%m-%Y', errors='coerce')

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2024-05-01', '2024-05-02', '2024-05-03', '2024-05-04',
#                '2024-05-05', '2024-05-06', '2024-05-07', '2024-05-08',
#                '2024-05-09', '2024-05-10'],
#               dtype='datetime64[ns]', name='DATE', length=19854, freq=None)

# %%
weather.index.year
# Out:
# Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#        ...
#        2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024, 2024],
#       dtype='int32', name='DATE', length=19854)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    365
# 2023    365
# 2024    131
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-05-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 2024-05-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 2024-05-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# ...

# %%
weather["target"]=weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-05-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 2024-05-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 2024-05-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
weather= weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-05-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 2024-05-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 2024-05-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# ...

# %%
import numpy as np

# %%
# Select only numeric columns
numeric_cols = weather.select_dtypes(include=[np.number]).columns

# Calculate correlation
corr_matrix = weather[numeric_cols].corr()

# Print the correlation matrix
print(corr_matrix)
# Out:
#             prcp      snow      snwd      tmax      tmin    target
# prcp    1.000000  0.146914  0.000942 -0.007945  0.051766 -0.003803
# snow    0.146914  1.000000  0.234205 -0.173790 -0.157957 -0.171447
# snwd    0.000942  0.234205  1.000000 -0.257212 -0.254264 -0.238572
# tmax   -0.007945 -0.173790 -0.257212  1.000000  0.955043  0.914844
# tmin    0.051766 -0.157957 -0.254264  0.955043  1.000000  0.914756
# target -0.003803 -0.171447 -0.238572  0.914844  0.914756  1.000000

# %%
from sklearn.linear_model import Ridge

# %%
rr=Ridge(alpha=.1)

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin'], dtype='object')

# %%
def backtest (weather, model, predictors, start=3650, step=90): 
    all_predictions = []
    
    for i in range(start, weather.shape[0], step): 
        train = weather.iloc[:i,:] 
        test = weather.iloc[i:(i+step),:]

        model.fit(train[predictors], train["target"])

        preds = model.predict(test[predictors])

        preds = pd.Series (preds, index=test.index) 
        combined = pd.concat([test ["target"], preds], axis=1)
        
        combined.columns = ["actual", "prediction"]

        combined ["diff"] = (combined ["prediction"] - combined ["actual"]).abs()

        all_predictions.append(combined) 
    return pd.concat(all_predictions,axis=0)

# %%
predictions = backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1979-12-30    43.0   50.229324   7.229324
# 1979-12-31    42.0   43.673798   1.673798
# 1980-01-01    41.0   41.579150   0.579150
# 1980-01-02    36.0   43.961887   7.961887
# 1980-01-03    30.0   40.204726  10.204726
# ...            ...         ...        ...
# 2024-05-06    77.0   69.375987   7.624013
# 2024-05-07    80.0   73.679485   6.320515
# 2024-05-08    71.0   75.473047   4.473047
# 2024-05-09    71.0   69.434818   1.565182
# 2024-05-10    71.0   69.434818   1.565182
#
# [16204 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error as mae

mae(predictions["actual"],predictions["prediction"])
# Out:
# 5.141938170899138

# %%
predictions["diff"].mean()
# Out:
# 5.141938170899138

# %%
def pct_diff(old,new) :
    return ( new - old ) / old
    
def compute_rolling (weather,horizon,col) :
    label = f"rolling_{horizon}_{col}"

    weather[label] = weather[col].rolling(horizon).mean()
    weather[f"{label}_pct"] =pct_diff(weather[label],weather[col])
    return weather

rolling_horizons =[3,14]

for horizon in rolling_horizons : 
    for col in ["tmax","tmin","prcp"] :
        weather = compute_rolling(weather,horizon,col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-05-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 2024-05-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 2024-05-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
weather = weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-05-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 2024-05-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 2024-05-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
weather =weather.fillna(0)

# %%
def expand_mean(df):
    return df.expanding(1).mean()

for col in ["tmax","tmin","prcp"] :
    weather[f"month_avg_{col}"] = weather[col].groupby(weather.index.month,group_keys=False).apply(expand_mean)
    weather[f"day_avg_{col}"] = weather[col].groupby(weather.index.day_of_year,group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2024-05-06  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 2024-05-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.06   0.0   0.0
# 2024-05-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2024-05-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
# ...

# %%
predictors = weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'day_avg_tmax', 'month_avg_tmin', 'day_avg_tmin', 'month_avg_prcp',
#        'day_avg_prcp'],
#       dtype='object')

# %%
predictions = backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction       diff
# DATE
# 1980-01-13    54.0   32.407593  21.592407
# 1980-01-14    51.0   44.687775   6.312225
# 1980-01-15    45.0   46.850038   1.850038
# 1980-01-16    40.0   42.206425   2.206425
# 1980-01-17    41.0   40.838566   0.161434
# ...            ...         ...        ...
# 2024-05-06    77.0   69.330632   7.669368
# 2024-05-07    80.0   72.329050   7.670950
# 2024-05-08    71.0   73.041943   2.041943
# 2024-05-09    71.0   69.848538   1.151462
# 2024-05-10    71.0   70.281778   0.718222
#
# [16190 rows x 3 columns]

# %%
mae(predictions["actual"],predictions["prediction"])
# Out:
# 4.793676864672529

# %%
predictions.sort_values("diff",ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 1990-03-12    85.0   54.361065  30.638935
# 2007-03-26    78.0   49.965413  28.034587
# 1998-03-26    80.0   51.966675  28.033325
# 2003-04-15    86.0   59.432179  26.567821
# 1985-04-18    84.0   58.425960  25.574040
# ...            ...         ...        ...
# 1987-09-16    75.0   75.001185   0.001185
# 1984-08-10    83.0   82.999179   0.000821
# 2011-09-25    78.0   77.999237   0.000763
# 1999-09-28    77.0   76.999245   0.000755
# 1984-12-24    47.0   46.999514   0.000486
#
# [16190 rows x 3 columns]

# %%
weather.loc["1990-03-07":"1990-03-17"]
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1990-03-07  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   2.0
# 1990-03-08  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   1.0
# 1990-03-09  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-10  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.01   0.0   0.0
# 1990-03-11  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.05   0.0   0.0
# 1990-03-12  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-13  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-14  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1990-03-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.26   0.0   0.0
#
# ...

# %%
predictions["diff"].round().value_counts().sort_index()
# Out:
# diff
# 0.0     1176
# 1.0     2240
# 2.0     2065
# 3.0     1901
# 4.0     1666
# 5.0     1430
# 6.0     1196
# 7.0     1044
# 8.0      828
# 9.0      701
# 10.0     531
# 11.0     388
# 12.0     322
# 13.0     203
# 14.0     152
# 15.0      96
# 16.0      80
# 17.0      57
# 18.0      33
# 19.0      25
# 20.0      13
# 21.0      14
# 22.0      11
# 23.0       7
# 24.0       4
# 25.0       2
# 26.0       1
# 27.0       1
# 28.0       2
# 31.0       1
# Name: count, dtype: int64

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
